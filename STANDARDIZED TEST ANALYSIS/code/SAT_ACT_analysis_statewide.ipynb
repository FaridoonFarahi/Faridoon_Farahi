# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ###### This analysis is aim at comparing and contrasting SAT and ACT score of all the states.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
# first creating a list for mean calculation
def mean(number_list):
    sum_of_numbers=sum(number_list)
    return sum_of_numbers/(len(number_list))
mean([1,2,3,4,5])
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(number_list):
    mean_std=mean(number_list)
    difference=[]
    for i in number_list:
        difference.append(mean_std-i)
    square=[]
    for i in difference:
        square.append(i**2)
    sum_= sum(square)
    variance= sum_/(len(number_list))
    return variance**0.5

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def data_cleaning(string):
    try:
        cleaning= float(string.replace('%', ''))
        return cleaning/100
    except:
        print('ERROR converting', string)

data_cleaning('50%')
# Out:
# 0.5

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Importing NumPy, Seaborn and Pandas.
import numpy as np
import pandas as pd
import seaborn as sns
# Importing matplotlib.pyplot.
import matplotlib.pyplot as plt
#Generate plots within the Jupyter notebook.
# %matplotlib inline

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
# importing ACT & SAT.
#sat_score_2019_ca = pd.read_csv('../data/sat_2019_ca.csv')
#act_score_2019_ca = pd.read_csv('../data/act_2019_ca.csv')
act_score_2019 = pd.read_csv('../data/act_2019.csv')
sat_score_2019 = pd.read_csv('../data/sat_2019.csv')
act_score_2017 = pd.read_csv('../data/act_2017.csv')
sat_score_2017 = pd.read_csv('../data/sat_2017.csv')
sat_score_2019_college = pd.read_csv('../data/sat_act_by_college.csv')

# %%
#printing the first five rows
sat_score_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
act_score_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
act_score_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
sat_score_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# get the sum of NaN entries in the dataframe
act_score_2019.isna().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
# get the sum of NaN entries in the dataframe
sat_score_2019.isna().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
# get the sum of NaN entries in the dataframe
act_score_2017.isna().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
# get the sum of NaN entries in the dataframe
sat_score_2017.isna().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# ##### 3. convert % data to floats

# %%
# grab the dash symbol
dash = sat_score_2019.iloc[39,1]
#replace '-' with NaN
sat_score_2019.replace(dash, np.NaN, inplace=True)
print(sat_score_2019.isna().sum())
# Out:
# State                 0
# Participation Rate    2
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
print(sat_score_2019.shape)
# drop rows with NaN
sat_score_2019.dropna(inplace=True)
sat_score_2019.shape
# Out:
# (53, 5)
# (51, 5)

# %%
# convert Participation Rate from '%' string to float
sat_score_2019['Participation Rate'] = sat_score_2019['Participation Rate'].apply(data_cleaning)
sat_score_2019.head()
# Out:
#         State  Participation Rate  EBRW  Math  Total
# 0     Alabama                0.07   583   560   1143
# 1      Alaska                0.41   556   541   1097
# 2     Arizona                0.31   569   565   1134
# 3    Arkansas                0.06   582   559   1141
# 4  California                0.63   534   531   1065

# %%
# convert Participation Rate from '%' string to float
act_score_2019['Participation'] = act_score_2019['Participation'].apply(data_cleaning)
act_score_2019.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       18.9
# 1      Alaska           0.38       20.1
# 2     Arizona           0.73       19.0
# 3    Arkansas           1.00       19.3
# 4  California           0.23       22.6

# %%
# convert Participation Rate from '%' string to float
sat_score_2017['Participation'] = sat_score_2017['Participation'].apply(data_cleaning)
sat_score_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
# convert Participation Rate from '%' string to float
act_score_2017['Participation'] = act_score_2017['Participation'].apply(data_cleaning)
act_score_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
# Renaming the columns and also using lowercase:
sat_score_2019.rename(columns={'State':'state', 'Participation Rate':'participation_2019', 'EBRW': 'ebrw_2019', 'Math':'math_2019', 'Total':'total_2019'}, inplace=True)
# Renaming the columns and also using lowercase:
sat_score_2017.rename(columns={'State':'state', 'Participation':'participation_2017', 'Evidence-Based Reading and Writing': 'ebrw_2017', 'Math':'math_2017', 'Total':'total_2017'}, inplace=True)

# Renaming the columns and also using lowercase:
act_score_2019.rename(columns={'State':'state', 'Participation':'participation_2019_act', 'composite': 'composite_2019_act'}, inplace=True)
# Renaming the columns and also using lowercase:
act_score_2017.rename(columns={'state_2017':'state', 'Participation':'participation_2017_act', 'english_2017': 'english_2017_act', 'Math':'math_2017_act', 'Reading':'reading_2017_act', 'Science':'science_2017_act', 'composite':'composite_2017_act'}, inplace=True)

# %%
act_score_2017.head(1)
# Out:
#       State  participation_2017_act  English  math_2017_act  reading_2017_act  \
# 0  National                     0.6     20.3           20.7              21.4
#
#    science_2017_act Composite
# 0              21.0      21.0

# %%
act_score_2019.head(1)
# Out:
#      state  participation_2019_act  Composite
# 0  Alabama                     1.0       18.9

# %%
sat_score_2019.head(1)
# Out:
#      state  participation_2019  ebrw_2019  math_2019  total_2019
# 0  Alabama                0.07        583        560        1143

# %%
sat_score_2017.head(1)
# Out:
#      state  participation_2017  ebrw_2017  math_2017  total_2017
# 0  Alabama                0.05        593        572        1165

# %%
# drop first row with 'National' as the state (not needed)
#act_score_2017.drop(index=0, inplace=True)
#act_score_2017.head()

# %%
# Renaming the columns and also using lowercase:
act_score_2017.rename(columns={'State':'state','reading_2017':'reading_2017_act', 'science_2017':'science_2017_act', 'Composite':'composite_2017_act'}, inplace=True)

# %%
act_score_2017.head(10)
# Out:
#                   state  participation_2017_act  English  math_2017_act  \
# 0              National                    0.60     20.3           20.7
# 1               Alabama                    1.00     18.9           18.4
# 2                Alaska                    0.65     18.7           19.8
# 3               Arizona                    0.62     18.6           19.8
# 4              Arkansas                    1.00     18.9           19.0
# 5            California                    0.31     22.5           22.7
# 6              Colorado                    1.00     20.1           20.3
# 7           Connecticut                    0.31     25.5           24.6
# 8              Delaware                    0.18     24.1           23.4
# 9  District of Columbia                    0.32     24.4           23.5
#
#    reading_2017_act  science_2017_act composite_2017_act
# 0              21.4              21.0               21.0
# 1              19.7              19.4               19.2
# ...

# %%
# find Distric of Coumbia
act_score_2017.head(9)
# Out:
#          state  participation_2017_act  English  math_2017_act  \
# 0     National                    0.60     20.3           20.7
# 1      Alabama                    1.00     18.9           18.4
# 2       Alaska                    0.65     18.7           19.8
# 3      Arizona                    0.62     18.6           19.8
# 4     Arkansas                    1.00     18.9           19.0
# 5   California                    0.31     22.5           22.7
# 6     Colorado                    1.00     20.1           20.3
# 7  Connecticut                    0.31     25.5           24.6
# 8     Delaware                    0.18     24.1           23.4
#
#    reading_2017_act  science_2017_act composite_2017_act
# 0              21.4              21.0               21.0
# 1              19.7              19.4               19.2
# 2              20.4              19.9               19.8
# 3              20.1              19.8               19.7
# ...

# %%
#act_score_2019.drop(index=8, inplace=True)
#act_score_2019.head(10)

# %%
# Merging SAT 2017 and SAT 2019 dataframes:
merge_sat = pd.merge(sat_score_2017, sat_score_2019)

# %%
merge_sat.head()
# Out:
#         state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 0     Alabama                0.05        593        572        1165
# 1      Alaska                0.38        547        533        1080
# 2     Arizona                0.30        563        553        1116
# 3    Arkansas                0.03        614        594        1208
# 4  California                0.53        531        524        1055
#
#    participation_2019  ebrw_2019  math_2019  total_2019
# 0                0.07        583        560        1143
# 1                0.41        556        541        1097
# 2                0.31        569        565        1134
# 3                0.06        582        559        1141
# 4                0.63        534        531        1065

# %%
merge_act= pd.merge(act_score_2017, act_score_2019)

# %%
merge_act.head()
# Out:
#       state  participation_2017_act  English  math_2017_act  reading_2017_act  \
# 0  National                    0.60     20.3           20.7              21.4
# 1   Alabama                    1.00     18.9           18.4              19.7
# 2    Alaska                    0.65     18.7           19.8              20.4
# 3   Arizona                    0.62     18.6           19.8              20.1
# 4  Arkansas                    1.00     18.9           19.0              19.7
#
#    science_2017_act composite_2017_act  participation_2019_act  Composite
# 0              21.0               21.0                    0.52       20.7
# 1              19.4               19.2                    1.00       18.9
# 2              19.9               19.8                    0.38       20.1
# 3              19.8               19.7                    0.73       19.0
# 4              19.5               19.4                    1.00       19.3

# %%
merge_sat.head()
# Out:
#         state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 0     Alabama                0.05        593        572        1165
# 1      Alaska                0.38        547        533        1080
# 2     Arizona                0.30        563        553        1116
# 3    Arkansas                0.03        614        594        1208
# 4  California                0.53        531        524        1055
#
#    participation_2019  ebrw_2019  math_2019  total_2019
# 0                0.07        583        560        1143
# 1                0.41        556        541        1097
# 2                0.31        569        565        1134
# 3                0.06        582        559        1141
# 4                0.63        534        531        1065

# %%
merge_2017_2019=pd.merge(merge_sat, merge_act)

# %%
merge_2017_2019.head()
# Out:
#         state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 0     Alabama                0.05        593        572        1165
# 1      Alaska                0.38        547        533        1080
# 2     Arizona                0.30        563        553        1116
# 3    Arkansas                0.03        614        594        1208
# 4  California                0.53        531        524        1055
#
#    participation_2019  ebrw_2019  math_2019  total_2019  \
# 0                0.07        583        560        1143
# 1                0.41        556        541        1097
# 2                0.31        569        565        1134
# 3                0.06        582        559        1141
# 4                0.63        534        531        1065
#
#    participation_2017_act  English  math_2017_act  reading_2017_act  \
# 0                    1.00     18.9           18.4              19.7
# 1                    0.65     18.7           19.8              20.4
# ...

# %%
merge_2017_2019.to_csv("merge_2017_2019.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\farid\\dsir-125\\projects\\project-01-main\\code'

# %%
merge_2017_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   participation_2017      51 non-null     float64
#  2   ebrw_2017               51 non-null     int64
#  3   math_2017               51 non-null     int64
#  4   total_2017              51 non-null     int64
#  5   participation_2019      51 non-null     float64
#  6   ebrw_2019               51 non-null     int64
#  7   math_2019               51 non-null     int64
#  8   total_2019              51 non-null     int64
#  9   participation_2017_act  51 non-null     float64
#  10  English                 51 non-null     float64
#  11  math_2017_act           51 non-null     float64
#  12  reading_2017_act        51 non-null     float64
#  13  science_2017_act        51 non-null     float64
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |state|participation_2017|ebrw_2017|math_2017|total_2017
# |---|---|---|---|---|
# |Alabama|5%|593|572|1165
# |Alaska|38%|547|533|1080
# |Arizona|30%|563|553|1116
# |Arkansas|3%|547|533|1080
# |California|5%|593|572|1165
# |Alaska|38%|547|533|1080

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#summary statistics
merge_2017_2019.describe()
# Out:
#        participation_2017   ebrw_2017   math_2017   total_2017  \
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.398039  569.117647  547.627451  1126.098039
# std              0.352766   45.666901   84.909119    92.494812
# min              0.020000  482.000000   52.000000   950.000000
# 25%              0.040000  533.500000  522.000000  1055.500000
# 50%              0.380000  559.000000  548.000000  1107.000000
# 75%              0.660000  613.000000  599.000000  1212.000000
# max              1.000000  644.000000  651.000000  1295.000000
#
#        participation_2019   ebrw_2019   math_2019   total_2019  \
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.490588  560.803922  552.196078  1113.078431
# std              0.387476   46.248035   51.290553    97.197910
# min              0.020000  483.000000  460.000000   943.000000
# 25%              0.055000  527.500000  511.500000  1038.000000
# ...

# %%
# EDA process for dictationary 
dict_sat_2019={}
numeric_colls=['math_2019', 'ebrw_2019']
for column in numeric_colls:
    #std_dev(sat_score_2019[column])
    dict_sat_2019[column]= std_dev(sat_score_2019[column])
print(dict_sat_2019)
# Out:
# {'math_2019': 50.78521461840036, 'ebrw_2019': 45.792378682545134}

# %%
{column : std_dev(sat_score_2019[column]) for column in numeric_colls }
# Out:
# {'math_2019': 50.78521461840036, 'ebrw_2019': 45.792378682545134}

# %%
merge_2017_2019.head(1)
# Out:
#      state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 0  Alabama                0.05        593        572        1165
#
#    participation_2019  ebrw_2019  math_2019  total_2019  \
# 0                0.07        583        560        1143
#
#    participation_2017_act  English  math_2017_act  reading_2017_act  \
# 0                     1.0     18.9           18.4              19.7
#
#    science_2017_act composite_2017_act  participation_2019_act  Composite
# 0              19.4               19.2                     1.0       18.9

# %%
# SAT 2017
row_num = merge_2017_2019['participation_2017'].argmin()
merge_2017_2019.iloc[row_num,0]
# Out:
# 'Iowa'

# %%
# sort on SAT 2017
merge_2017_2019.sort_values('participation_2017').head() # lowest
# Out:
#            state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 34  North Dakota                0.02        635        621        1256
# 24   Mississippi                0.02        634        607        1242
# 15          Iowa                0.02        641        635        1275
# 25      Missouri                0.03        640        631        1271
# 44          Utah                0.03        624        614        1238
#
#     participation_2019  ebrw_2019  math_2019  total_2019  \
# 34                0.02        627        636        1263
# 24                0.03        628        608        1237
# 15                0.03        622        622        1244
# 25                0.04        622        615        1236
# 44                0.04        614        615        1230
#
#     participation_2017_act  English  math_2017_act  reading_2017_act  \
# 34                    0.98     19.0           20.4              20.5
# ...

# %%
# sort on SAT 2017
merge_2017_2019.sort_values('participation_2017', ascending=False).head() # highest
# Out:
#                    state  participation_2017  ebrw_2017  math_2017  \
# 8   District of Columbia                1.00        482        468
# 22              Michigan                1.00        509        495
# 6            Connecticut                1.00        530        512
# 7               Delaware                1.00        503        492
# 29         New Hampshire                0.96        532        520
#
#     total_2017  participation_2019  ebrw_2019  math_2019  total_2019  \
# 8          950                0.94        495        480         975
# 22        1005                1.00        507        496        1003
# 6         1041                1.00        529        516        1046
# 7          996                1.00        499        486         985
# 29        1052                0.95        533        526        1059
#
#     participation_2017_act  English  math_2017_act  reading_2017_act  \
# 8                     0.32     24.4           23.5              24.9
# ...

# %%
# sort on SAT 2019
merge_2017_2019.sort_values('participation_2019').head() # lowest
# Out:
#            state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 34  North Dakota                0.02        635        621        1256
# 50       Wyoming                0.03        626        604        1230
# 41  South Dakota                0.03        612        603        1216
# 27      Nebraska                0.03        629        625        1253
# 49     Wisconsin                0.03        642        649        1291
#
#     participation_2019  ebrw_2019  math_2019  total_2019  \
# 34                0.02        627        636        1263
# 50                0.03        623        615        1238
# 41                0.03        633        635        1268
# 27                0.03        628        631        1260
# 49                0.03        635        648        1283
#
#     participation_2017_act  English  math_2017_act  reading_2017_act  \
# 34                    0.98     19.0           20.4              20.5
# ...

# %%
# sort on SAT 2019
merge_2017_2019.sort_values('participation_2019', ascending=False).head() # highest
# Out:
#            state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 39  Rhode Island                0.71        539        524        1062
# 13      Illinois                0.09        559        556        1115
# 22      Michigan                1.00        509        495        1005
# 5       Colorado                0.11        606        595        1201
# 6    Connecticut                1.00        530        512        1041
#
#     participation_2019  ebrw_2019  math_2019  total_2019  \
# 39                 1.0        503        492         995
# 13                 1.0        509        504        1013
# 22                 1.0        507        496        1003
# 5                  1.0        518        506        1024
# 6                  1.0        529        516        1046
#
#     participation_2017_act  English  math_2017_act  reading_2017_act  \
# 39                    0.21     24.0           23.3              24.7
# ...

# %%
# ACT lowest and highest participation

# %%
merge_2017_2019.columns
# Out:
# Index(['state', 'participation_2017', 'ebrw_2017', 'math_2017', 'total_2017',
#        'participation_2019', 'ebrw_2019', 'math_2019', 'total_2019',
#        'participation_2017_act', 'English', 'math_2017_act',
#        'reading_2017_act', 'science_2017_act', 'composite_2017_act',
#        'participation_2019_act', 'Composite'],
#       dtype='object')

# %%
# need double pair of [[ ]] to select from more than one column
part = merge_2017_2019[['state','participation_2017', 'participation_2019', 'participation_2017_act', 'participation_2019_act']]
part.head()
# Out:
#         state  participation_2017  participation_2019  participation_2017_act  \
# 0     Alabama                0.05                0.07                    1.00
# 1      Alaska                0.38                0.41                    0.65
# 2     Arizona                0.30                0.31                    0.62
# 3    Arkansas                0.03                0.06                    1.00
# 4  California                0.53                0.63                    0.31
#
#    participation_2019_act
# 0                    1.00
# 1                    0.38
# 2                    0.73
# 3                    1.00
# 4                    0.23

# %%
part[ part['state']=='Idaho' ]
# Out:
#     state  participation_2017  participation_2019  participation_2017_act  \
# 12  Idaho                0.93                 1.0                    0.38
#
#     participation_2019_act
# 12                    0.31

# %%
part.iloc[11,1]  # iloc [row#, col#]
# Out:
# 0.55

# %%
part.loc[11,'participation_2017']  # .loc uses string names
# Out:
# 0.55

# %%
# find states with 100% participation in any of the 4 tests
#  note: each condition MUST be in ( )
#  & is the 'and' operator,  | is the 'or' operator
cond = (part['participation_2017']==1.0) | (part['participation_2019']==1.0) | (part['participation_2017_act']==1.0) | (part['participation_2019_act']==1.0) 
   
part[cond].head()
# Out:
#          state  participation_2017  participation_2019  \
# 0      Alabama                0.05                0.07
# 3     Arkansas                0.03                0.06
# 5     Colorado                0.11                1.00
# 6  Connecticut                1.00                1.00
# 7     Delaware                1.00                1.00
#
#    participation_2017_act  participation_2019_act
# 0                    1.00                    1.00
# 3                    1.00                    1.00
# 5                    1.00                    0.27
# 6                    0.31                    0.22
# 7                    0.18                    0.13

# %%
part.head()
# Out:
#         state  participation_2017  participation_2019  participation_2017_act  \
# 0     Alabama                0.05                0.07                    1.00
# 1      Alaska                0.38                0.41                    0.65
# 2     Arizona                0.30                0.31                    0.62
# 3    Arkansas                0.03                0.06                    1.00
# 4  California                0.53                0.63                    0.31
#
#    participation_2019_act
# 0                    1.00
# 1                    0.38
# 2                    0.73
# 3                    1.00
# 4                    0.23

# %%
# Do any states show have >50% participation on both tests each year?

# %%
part.columns
# Out:
# Index(['state', 'participation_2017', 'participation_2019',
#        'participation_2017_act', 'participation_2019_act'],
#       dtype='object')

# %%
cond = (part.participation_2017 > 0.5) & (part.participation_2019 > 0.5) & (part.participation_2017_act >0.5) & (part.participation_2019_act >0.5)
part[ cond ]
# Out:
#       state  participation_2017  participation_2019  participation_2017_act  \
# 9   Florida                0.83                1.00                    0.73
# 11   Hawaii                0.55                0.54                    0.90
#
#     participation_2019_act
# 9                     0.54
# 11                    0.80

# %%
# answer:  only Hawaii

# %% [markdown]
# **Compare SAT Scores 2017 to 2019**

# %%
sat_score_2017.head()
# Out:
#         state  participation_2017  ebrw_2017  math_2017  total_2017
# 0     Alabama                0.05        593        572        1165
# 1      Alaska                0.38        547        533        1080
# 2     Arizona                0.30        563        553        1116
# 3    Arkansas                0.03        614        594        1208
# 4  California                0.53        531        524        1055

# %%
sat_score_2019.head()
# Out:
#         state  participation_2019  ebrw_2019  math_2019  total_2019
# 0     Alabama                0.07        583        560        1143
# 1      Alaska                0.41        556        541        1097
# 2     Arizona                0.31        569        565        1134
# 3    Arkansas                0.06        582        559        1141
# 4  California                0.63        534        531        1065

# %%
# use list to select more than one column
sat_2017_totals = sat_score_2017[['state','total_2017']]
sat_2017_totals.set_index('state', inplace=True)
sat_2017_totals.head()
# Out:
#             total_2017
# state
# Alabama           1165
# Alaska            1080
# Arizona           1116
# Arkansas          1208
# California        1055

# %%
# select just state and total columns and make 'state' the index
sat_2019_totals = sat_score_2019[['state','total_2019']]
sat_2019_totals.set_index('state', inplace=True)
sat_2019_totals.head()
# Out:
#             total_2019
# state
# Alabama           1143
# Alaska            1097
# Arizona           1134
# Arkansas          1141
# California        1065

# %%
# combine the 2017 and 2019 dataframes
sat_totals = sat_2017_totals.join(sat_2019_totals)

# %%
# ACT

# %%
# REMOVE THIS CELL
# use list to select more than one column
sat_2017_totals = sat_score_2017[['state','total_2017']]
sat_2017_totals.set_index('state', inplace=True)
sat_2017_totals.head()

# select just state and total columns and make 'state' the index
sat_2019_totals = sat_score_2019[['state','total_2019']]
sat_2019_totals.set_index('state', inplace=True)
sat_2019_totals.head()

# combine the 2017 and 2019 dataframes
sat_totals = sat_2017_totals.join(sat_2019_totals)

# %%
sat_totals.head()
# Out:
#             total_2017  total_2019
# state
# Alabama           1165        1143
# Alaska            1080        1097
# Arizona           1116        1134
# Arkansas          1208        1141
# California        1055        1065

# %%
# create an 'Increase' column where True means total score increased from 2017 to 2019
sat_totals['Increase'] = sat_totals.total_2019 > sat_totals.total_2017

# %%
sat_totals.head()
# Out:
#             total_2017  total_2019  Increase
# state
# Alabama           1165        1143     False
# Alaska            1080        1097      True
# Arizona           1116        1134      True
# Arkansas          1208        1141     False
# California        1055        1065      True

# %%
# use groupby to count the number of states with and without increses
sat_totals.groupby('Increase')['Increase'].count()
# Out:
# Increase
# False    26
# True     25
# Name: Increase, dtype: int64

# %%
sat_score_2017.head(1)
# Out:
#      state  participation_2017  ebrw_2017  math_2017  total_2017
# 0  Alabama                0.05        593        572        1165

# %%
# use list to select more than one column
sat_2017_ebrw = sat_score_2017[['state','ebrw_2017']]
sat_2017_ebrw.set_index('state', inplace=True)
sat_2017_ebrw.head()
# Out:
#             ebrw_2017
# state
# Alabama           593
# Alaska            547
# Arizona           563
# Arkansas          614
# California        531

# %%
# select just state and ebrw columns and make 'state' the index
sat_2019_ebrw = sat_score_2019[['state','ebrw_2019']]
sat_2019_ebrw.set_index('state', inplace=True)
sat_2019_ebrw.head()
# Out:
#             ebrw_2019
# state
# Alabama           583
# Alaska            556
# Arizona           569
# Arkansas          582
# California        534

# %%
# combine the 2017 and 2019 dataframes
sat_ebrw = sat_2017_ebrw.join(sat_2019_ebrw)
sat_ebrw.head()
# Out:
#             ebrw_2017  ebrw_2019
# state
# Alabama           593        583
# Alaska            547        556
# Arizona           563        569
# Arkansas          614        582
# California        531        534

# %%
# create an 'Increase' column where True means ebrw score increased from 2017 to 2019
sat_ebrw['Increase'] = sat_ebrw.ebrw_2019 > sat_ebrw.ebrw_2017
sat_ebrw.head()
# Out:
#             ebrw_2017  ebrw_2019  Increase
# state
# Alabama           593        583     False
# Alaska            547        556      True
# Arizona           563        569      True
# Arkansas          614        582     False
# California        531        534      True

# %%
# use groupby to count the number of states with and without increses
sat_ebrw.groupby('Increase')['Increase'].count()
# Out:
# Increase
# False    33
# True     18
# Name: Increase, dtype: int64

# %%
# use list to select more than one column
sat_2017_math = sat_score_2017[['state','math_2017']]
sat_2017_math.set_index('state', inplace=True)
sat_2017_math.head()
# Out:
#             math_2017
# state
# Alabama           572
# Alaska            533
# Arizona           553
# Arkansas          594
# California        524

# %%
# select just state and math columns and make 'state' the index
sat_2019_math = sat_score_2019[['state','math_2019']]
sat_2019_math.set_index('state', inplace=True)
sat_2019_math.head()
# Out:
#             math_2019
# state
# Alabama           560
# Alaska            541
# Arizona           565
# Arkansas          559
# California        531

# %%
# combine the 2017 and 2019 dataframes
sat_math = sat_2017_math.join(sat_2019_math)
sat_math.head()
# Out:
#             math_2017  math_2019
# state
# Alabama           572        560
# Alaska            533        541
# Arizona           553        565
# Arkansas          594        559
# California        524        531

# %%
# create an 'Increase' column where True means math score increased from 2017 to 2019
sat_math['Increase'] = sat_math.math_2019 > sat_math.math_2017
sat_math.head()
# Out:
#             math_2017  math_2019  Increase
# state
# Alabama           572        560     False
# Alaska            533        541      True
# Arizona           553        565      True
# Arkansas          594        559     False
# California        524        531      True

# %%
# use groupby to count the number of states with and without increses
sat_math.groupby('Increase')['Increase'].count()
# Out:
# Increase
# False    22
# True     29
# Name: Increase, dtype: int64

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Get ACT totals

# %%
act_score_2017.head(1)
# Out:
#       state  participation_2017_act  English  math_2017_act  reading_2017_act  \
# 0  National                     0.6     20.3           20.7              21.4
#
#    science_2017_act composite_2017_act
# 0              21.0               21.0

# %%
# use list to select more than one column
act_2017_totals = act_score_2017[['state','composite_2017_act']]
act_2017_totals.set_index('state', inplace=True)
act_2017_totals.head()
# Out:
#          composite_2017_act
# state
# National               21.0
# Alabama                19.2
# Alaska                 19.8
# Arizona                19.7
# Arkansas               19.4

# %%
act_score_2019.head()
# Out:
#         state  participation_2019_act  Composite
# 0     Alabama                    1.00       18.9
# 1      Alaska                    0.38       20.1
# 2     Arizona                    0.73       19.0
# 3    Arkansas                    1.00       19.3
# 4  California                    0.23       22.6

# %%
act_score_2019.head(1)
# Out:
#      state  participation_2019_act  Composite
# 0  Alabama                     1.0       18.9

# %%
act_score_2019.rename(columns={'Composite':'composite_2019_act'}, inplace=True)

# %%
# select just state and total columns and make 'state' the index
act_2019_totals = act_score_2019[['state','composite_2019_act']]
act_2019_totals.set_index('state', inplace=True)
act_2019_totals.head()
# Out:
#             composite_2019_act
# state
# Alabama                   18.9
# Alaska                    20.1
# Arizona                   19.0
# Arkansas                  19.3
# California                22.6

# %%
# combine the 2017 and 2019 dataframes
act_totals = act_2017_totals.join(act_2019_totals)

# %%
act_totals.head()
# Out:
#          composite_2017_act  composite_2019_act
# state
# National               21.0                20.7
# Alabama                19.2                18.9
# Alaska                 19.8                20.1
# Arizona                19.7                19.0
# Arkansas               19.4                19.3

# %%
sat_totals2 = sat_totals.drop('Increase', axis=1)

# %%
sat_totals2.head()
# Out:
#             total_2017  total_2019
# state
# Alabama           1165        1143
# Alaska            1080        1097
# Arizona           1116        1134
# Arkansas          1208        1141
# California        1055        1065

# %%
# combine sat and act totals
df_totals = sat_totals2.join(act_totals)
df_totals.head()
# Out:
#             total_2017  total_2019 composite_2017_act  composite_2019_act
# state
# Alabama           1165        1143               19.2                18.9
# Alaska            1080        1097               19.8                20.1
# Arizona           1116        1134               19.7                19.0
# Arkansas          1208        1141               19.4                19.3
# California        1055        1065               22.8                22.6

# %%
# Transpose the SAT df
sat_totals_t = sat_totals2.T
sat_totals_t
# Out:
# state       Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# total_2017     1165    1080     1116      1208        1055      1201
# total_2019     1143    1097     1134      1141        1065      1024
#
# state       Connecticut  Delaware  District of Columbia  Florida  ...  \
# total_2017         1041       996                   950     1017  ...
# total_2019         1046       985                   975      999  ...
#
# state       South Dakota  Tennessee  Texas  Utah  Vermont  Virginia  \
# total_2017          1216       1228   1020  1238     1114      1102
# total_2019          1268       1220   1022  1230     1106      1119
#
# state       Washington  West Virginia  Wisconsin  Wyoming
# total_2017        1075           1086       1291     1230
# total_2019        1074            943       1283     1238
#
# [2 rows x 51 columns]

# %%
sat_2017_totals_s = sat_2017_totals.sort_values('total_2017')
sat_2017_totals_s.head()
# Out:
#                       total_2017
# state
# District of Columbia         950
# Delaware                     996
# Idaho                       1005
# Michigan                    1005
# Maine                       1012

# %%
plt.scatter(sat_2017_totals.total_2017, sat_2019_totals.total_2019)
x = [n for n in range(950,1300)]
y = x
plt.title('2019 SAT Totals vs 2017 SAT Totals')
plt.plot(x,y)
plt.xlabel('2017')
plt.ylabel('2019')
# states falling on the diagonal line scored the same in both years
# shows that most states did about the same in 2019 as 2017
# a few states did a little better in 2019 than 2017
# 9 states did quite a bit worse in 2019 than 2017
# Out:
# Text(0, 0.5, '2019')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,10))

act_score_2019['participation_2019_act'].hist(ax=ax[0])
ax[0].set_xlabel('Participation Rate in ACT 2019')

act_score_2017['participation_2017_act'].hist(ax=ax[1])
ax[1].set_xlabel('Participation Rate in ACT 2017')
# Out:
# Text(0.5, 0, 'Participation Rate in ACT 2017')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,10))

sat_score_2019['total_2019'].hist(ax=ax[0])
ax[0].set_xlabel('Total Score in SAT 2019')

sat_score_2017['total_2017'].hist(ax=ax[1])
ax[1].set_xlabel('Total Score in SAT 2017')
# Out:
# Text(0.5, 0, 'Total Score in SAT 2017')

# %%
merge_2017_2019.head(2)
# Out:
#      state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 0  Alabama                0.05        593        572        1165
# 1   Alaska                0.38        547        533        1080
#
#    participation_2019  ebrw_2019  math_2019  total_2019  \
# 0                0.07        583        560        1143
# 1                0.41        556        541        1097
#
#    participation_2017_act  English  math_2017_act  reading_2017_act  \
# 0                    1.00     18.9           18.4              19.7
# 1                    0.65     18.7           19.8              20.4
#
#    science_2017_act composite_2017_act  participation_2019_act  Composite
# 0              19.4               19.2                    1.00       18.9
# 1              19.9               19.8                    0.38       20.1

# %%
fig,ax = plt.subplots(figsize=(15,10))
sns.heatmap(merge_2017_2019.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
merge_2017_2019.head()
# Out:
#         state  participation_2017  ebrw_2017  math_2017  total_2017  \
# 0     Alabama                0.05        593        572        1165
# 1      Alaska                0.38        547        533        1080
# 2     Arizona                0.30        563        553        1116
# 3    Arkansas                0.03        614        594        1208
# 4  California                0.53        531        524        1055
#
#    participation_2019  ebrw_2019  math_2019  total_2019  \
# 0                0.07        583        560        1143
# 1                0.41        556        541        1097
# 2                0.31        569        565        1134
# 3                0.06        582        559        1141
# 4                0.63        534        531        1065
#
#    participation_2017_act  English  math_2017_act  reading_2017_act  \
# 0                    1.00     18.9           18.4              19.7
# 1                    0.65     18.7           19.8              20.4
# ...

# %%
# find best 10 and worst ten SAT totals 2017
sat_2017_worst = sat_2017_totals_s[0:10]
print(sat_2017_worst)
sat_2017_best = sat_2017_totals_s[-10:]
print(sat_2017_best)
# Out:
#                       total_2017
# state
# District of Columbia         950
# Delaware                     996
# Idaho                       1005
# Michigan                    1005
# Maine                       1012
# Florida                     1017
# Texas                       1020
# Connecticut                 1041
# Oklahoma                    1047
# Georgia                     1050
#               total_2017
# state
# Utah                1238
# Mississippi         1242
# Kentucky            1247
# Nebraska            1253
# North Dakota        1256
# Kansas              1260
# Missouri            1271
# Iowa                1275
# Wisconsin           1291
# Minnesota           1295

# %%
# find best 10 and worst ten SAT totals 2019
worst_2017 = sat_2017_worst.index
sat_2019_worst = sat_2019_totals.loc[worst_2017]

best_2017 = sat_2017_best.index
sat_2019_best = sat_2019_totals.loc[best_2017]

sat_2019_best
# Out:
#               total_2019
# state
# Utah                1230
# Mississippi         1237
# Kentucky            1232
# Nebraska            1260
# North Dakota        1263
# Kansas              1241
# Missouri            1236
# Iowa                1244
# Wisconsin           1283
# Minnesota           1284

# %%
# bar chart for how the worst SAT states (in 2017) did in 2019
x_even = [n*2 for n in range(10)]
x_odd = [n+1 for n in x_even]

plt.bar(x_even,sat_2017_worst['total_2017'])
plt.bar(x_odd, sat_2019_worst['total_2019'])
plt.title('Ten states with worst SAT scores in 2017 and 2019')
plt.xticks(x_even, worst_2017, rotation=90);

# %%
# bar chart for how the best SAT states (in 2017) did in 2019
x_even = [n*2 for n in range(10)]
x_odd = [n+1 for n in x_even]

plt.bar(x_even,sat_2017_best['total_2017'])
plt.bar(x_odd, sat_2019_best['total_2019'])
plt.title('Ten states with best SAT scores in 2017 and 2019')
plt.xticks(x_even, best_2017, rotation=90);

# %% [markdown]
# ## Conclusions

# %% [markdown]
# 1. SAT EBRW of 18 states have increase while 33 have decreased from 2017 to 2019
# 2. SAT Math of 29 states have increase while 22 have decreased from 2017 to 2019
# 3. SAT Totals of 26 states have increase while 25 have decreased from 2017 to 2019
# 4. Top ten states with highest SAT scores from 2017 to 2019 remains the same. Mostly in Mid-West.

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
